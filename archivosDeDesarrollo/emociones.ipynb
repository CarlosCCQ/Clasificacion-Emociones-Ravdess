# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import joblib
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# %matplotlib inline

DATASET_PATH = "/home/jhan/Documentos/archive"
MODEL_PATH = "/home/jhan/Documentos/modelo"
os.makedirs(MODEL_PATH, exist_ok=True)

# %% [markdown]
# # Analysis

# %%
def plot_waveform(file_path):
    try:
        data, sr = librosa.load(file_path, sr=22050)
        plt.figure(figsize=(15,5))
        librosa.display.waveshow(data, sr=sr)
        plt.title(os.path.basename(file_path))
        plt.show()
    except Exception as e:
        print(f"Error: {str(e)}")

example_audio = os.path.join(DATASET_PATH, "Actor_01", "03-01-01-01-01-01-01.wav")
print("¿Archivo existe?:", os.path.exists(example_audio))
plot_waveform(example_audio)
# Out:
# ¿Archivo existe?: True

# %%
features = []
labels = []

for root, _, files in os.walk(DATASET_PATH):
    for file in files:
        if not file.endswith(".wav"):
            continue
        try:
            file_path = os.path.join(root, file)
            X, sr = librosa.load(file_path, sr=22050, duration=3)

            mfccs = librosa.feature.mfcc(y=X, sr=sr, n_mfcc=40)
            delta = librosa.feature.delta(mfccs)
            combined = np.vstack([mfccs, delta]).T
            
            features.append(combined)
            labels.append(file.split("-")[2])
            
        except Exception as e:
            print(f"Error en {file}: {str(e)}")
            continue

print("\nVerificación:")
print(f"Muestras: {len(features)} | Pasos temporales: {len(features[0])} | Características: {len(features[0][0])}")
print("Distribución de clases:", pd.Series(labels).value_counts().sort_index())
# Out:
# Verificación:
# Muestras: 2880 | Pasos temporales: 130 | Características: 80
# Distribución de clases: 01    192
# 02    384
# 03    384
# 04    384
# 05    384
# 06    384
# 07    384
# 08    384
# Name: count, dtype: int64

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_length = 130
X_padded = pad_sequences(
    features, 
    maxlen=max_length, 
    dtype="float32", 
    padding="post", 
    truncating="post"
)

y = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(
    X_padded, 
    y, 
    test_size=0.25, 
    stratify=y, 
    random_state=42
)

print("\nDatos finales:")
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# Datos finales:
# X_train: (2160, 130, 80)
# X_test: (720, 130, 80)

# %% [markdown]
# # Decision Tree Classifier

# %%
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

dtree = DecisionTreeClassifier(
    max_depth=12,
    min_samples_split=10,
    class_weight="balanced",
    random_state=42
)

dtree.fit(X_train_flat, y_train)
y_pred = dtree.predict(X_test_flat)

print("\nDecision Tree - Reporte:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Decision Tree - Reporte:
#               precision    recall  f1-score   support
#
#           01      0.596     0.646     0.620        48
#           02      0.738     0.792     0.764        96
#           03      0.658     0.760     0.705        96
#           04      0.637     0.604     0.620        96
#           05      0.633     0.646     0.639        96
#           06      0.756     0.646     0.697        96
#           07      0.716     0.604     0.655        96
#           08      0.618     0.656     0.636        96
#
#     accuracy                          0.671       720
#    macro avg      0.669     0.669     0.667       720
# weighted avg      0.674     0.671     0.670       720

# %%
joblib.dump(dtree, os.path.join(MODEL_PATH, "decision_tree_40mfccs.joblib"))
print(f"Modelo guardado en: {os.path.join(MODEL_PATH, 'decision_tree_40mfccs.joblib')}")
# Out:
# Modelo guardado en: /home/jhan/Documentos/modelo/decision_tree_40mfccs.joblib

# %% [markdown]
# # Random Forest

# %%
rforest = RandomForestClassifier(
    n_estimators=200,
    max_depth=15,
    max_features="sqrt",
    class_weight="balanced",
    n_jobs=-1,
    random_state=42,
    verbose=1
)

rforest.fit(X_train_flat, y_train)
y_pred = rforest.predict(X_test_flat)

print("\nRandom Forest - Reporte:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    8.7s
# Random Forest - Reporte:
#               precision    recall  f1-score   support
#
#           01      0.900     0.750     0.818        48
#           02      0.671     0.979     0.797        96
#           03      0.833     0.729     0.778        96
#           04      0.941     0.667     0.780        96
#           05      0.796     0.812     0.804        96
#           06      0.929     0.812     0.867        96
#           07      0.768     0.896     0.827        96
#           08      0.872     0.854     0.863        96
#
#     accuracy                          0.817       720
#    macro avg      0.839     0.812     0.817       720
# weighted avg      0.835     0.817     0.817       720
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    9.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.1s finished

# %%
joblib.dump(rforest, os.path.join(MODEL_PATH, "random_forest_40mfccs.joblib"))
print(f"Modelo guardado en: {os.path.join(MODEL_PATH, 'random_forest_40mfccs.joblib')}")
# Out:
# Modelo guardado en: /home/jhan/Documentos/modelo/random_forest_40mfccs.joblib

# %% [markdown]
# # Natural network

# %%
x_traincnn = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
x_testcnn = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

print("\nVerificación de dimensiones CNN:")
print("x_traincnn.shape:", x_traincnn.shape)
print("x_testcnn.shape:", x_testcnn.shape)
# Out:
# Verificación de dimensiones CNN:
# x_traincnn.shape: (2160, 130, 80, 1)
# x_testcnn.shape: (720, 130, 80, 1)

# %%
le = LabelEncoder()
y_train_int = le.fit_transform(y_train)
y_test_int = le.transform(y_test)

print("\nEtiquetas codificadas:")
print("Clases originales:", le.classes_)
print("Ejemplo y_train_int:", y_train_int[:5])
print("Ejemplo y_test_int:", y_test_int[:5])
# Out:
# Etiquetas codificadas:
# Clases originales: ['01' '02' '03' '04' '05' '06' '07' '08']
# Ejemplo y_train_int: [0 1 4 6 1]
# Ejemplo y_test_int: [7 2 6 5 3]

# %%
model = Sequential()

model.add(Conv1D(256, 5, activation="relu", input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(BatchNormalization())
model.add(MaxPooling1D(2))
model.add(Dropout(0.3))

model.add(Conv1D(128, 3, activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling1D(2))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(len(le.classes_), activation="softmax"))

opt = Adam(learning_rate=0.0001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 126, 256)          102656
#
#  batch_normalization (Batch  (None, 126, 256)          1024
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 63, 256)           0
#  D)
#
#  dropout (Dropout)           (None, 63, 256)           0
#
#  conv1d_1 (Conv1D)           (None, 61, 128)           98432
#
#  batch_normalization_1 (Bat  (None, 61, 128)           512
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 30, 128)           0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  flatten (Flatten)           (None, 3840)              0
#
#  dense (Dense)               (None, 64)                245824
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 448968 (1.71 MB)
# Trainable params: 448200 (1.71 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=5)
]

cnnhistory = model.fit(
    x_traincnn,
    y_train_int,
    batch_size=32,
    epochs=100,
    validation_data=(x_testcnn, y_test_int),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 2025-07-04 18:25:04.741788: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 89856000 exceeds 10% of free system memory.
# 68/68 [==============================] - ETA: 0s - loss: 3.8347 - accuracy: 0.1755
# 2025-07-04 18:25:16.575603: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 29952000 exceeds 10% of free system memory.
# 68/68 [==============================] - 13s 143ms/step - loss: 3.8347 - accuracy: 0.1755 - val_loss: 3.4341 - val_accuracy: 0.2028 - lr: 1.0000e-04
# Epoch 2/100
# 68/68 [==============================] - 9s 135ms/step - loss: 3.2258 - accuracy: 0.2440 - val_loss: 3.0810 - val_accuracy: 0.2861 - lr: 1.0000e-04
# Epoch 3/100
# 68/68 [==============================] - 9s 128ms/step - loss: 3.0759 - accuracy: 0.2829 - val_loss: 2.9009 - val_accuracy: 0.3944 - lr: 1.0000e-04
# Epoch 4/100
# 68/68 [==============================] - 8s 123ms/step - loss: 2.9731 - accuracy: 0.3273 - val_loss: 2.7930 - val_accuracy: 0.4333 - lr: 1.0000e-04
# Epoch 5/100
# 68/68 [==============================] - 8s 122ms/step - loss: 2.9064 - accuracy: 0.3431 - val_loss: 2.6887 - val_accuracy: 0.4486 - lr: 1.0000e-04
# Epoch 6/100
# 68/68 [==============================] - 8s 120ms/step - loss: 2.8398 - accuracy: 0.3639 - val_loss: 2.5914 - val_accuracy: 0.4806 - lr: 1.0000e-04
# Epoch 7/100
# 68/68 [==============================] - 8s 122ms/step - loss: 2.7175 - accuracy: 0.3949 - val_loss: 2.4983 - val_accuracy: 0.5194 - lr: 1.0000e-04
# Epoch 8/100
# 68/68 [==============================] - 8s 120ms/step - loss: 2.6688 - accuracy: 0.4227 - val_loss: 2.4152 - val_accuracy: 0.5389 - lr: 1.0000e-04
# Epoch 9/100
# 68/68 [==============================] - 8s 123ms/step - loss: 2.6037 - accuracy: 0.4157 - val_loss: 2.3668 - val_accuracy: 0.5458 - lr: 1.0000e-04
# Epoch 10/100
# 68/68 [==============================] - 8s 119ms/step - loss: 2.4993 - accuracy: 0.4565 - val_loss: 2.3097 - val_accuracy: 0.5583 - lr: 1.0000e-04
# Epoch 11/100
# 68/68 [==============================] - 8s 121ms/step - loss: 2.4355 - accuracy: 0.4773 - val_loss: 2.2268 - val_accuracy: 0.5931 - lr: 1.0000e-04
# Epoch 12/100
# 68/68 [==============================] - 8s 120ms/step - loss: 2.3938 - accuracy: 0.4912 - val_loss: 2.1544 - val_accuracy: 0.5958 - lr: 1.0000e-04
# Epoch 13/100
# 68/68 [==============================] - 8s 123ms/step - loss: 2.3123 - accuracy: 0.5037 - val_loss: 2.0858 - val_accuracy: 0.6083 - lr: 1.0000e-04
# Epoch 14/100
# 68/68 [==============================] - 8s 124ms/step - loss: 2.2304 - accuracy: 0.5398 - val_loss: 2.0155 - val_accuracy: 0.6278 - lr: 1.0000e-04
# Epoch 15/100
# 68/68 [==============================] - 9s 129ms/step - loss: 2.1588 - accuracy: 0.5532 - val_loss: 1.9570 - val_accuracy: 0.6569 - lr: 1.0000e-04
# Epoch 16/100
# 68/68 [==============================] - 5s 77ms/step - loss: 2.0832 - accuracy: 0.5792 - val_loss: 1.9251 - val_accuracy: 0.6514 - lr: 1.0000e-04
# Epoch 17/100
# 68/68 [==============================] - 5s 75ms/step - loss: 2.0345 - accuracy: 0.5949 - val_loss: 1.8427 - val_accuracy: 0.6861 - lr: 1.0000e-04
# Epoch 18/100
# 68/68 [==============================] - 5s 75ms/step - loss: 1.9602 - accuracy: 0.6157 - val_loss: 1.8141 - val_accuracy: 0.6778 - lr: 1.0000e-04
# Epoch 19/100
# 68/68 [==============================] - 5s 75ms/step - loss: 1.9035 - accuracy: 0.6278 - val_loss: 1.7379 - val_accuracy: 0.7028 - lr: 1.0000e-04
# Epoch 20/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.8535 - accuracy: 0.6495 - val_loss: 1.7156 - val_accuracy: 0.7014 - lr: 1.0000e-04
# Epoch 21/100
# 68/68 [==============================] - 5s 74ms/step - loss: 1.8010 - accuracy: 0.6519 - val_loss: 1.6804 - val_accuracy: 0.7014 - lr: 1.0000e-04
# Epoch 22/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.7193 - accuracy: 0.6903 - val_loss: 1.6108 - val_accuracy: 0.7264 - lr: 1.0000e-04
# Epoch 23/100
# 68/68 [==============================] - 5s 74ms/step - loss: 1.7219 - accuracy: 0.6824 - val_loss: 1.6069 - val_accuracy: 0.7361 - lr: 1.0000e-04
# Epoch 24/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.6427 - accuracy: 0.7019 - val_loss: 1.5002 - val_accuracy: 0.7639 - lr: 1.0000e-04
# Epoch 25/100
# 68/68 [==============================] - 5s 74ms/step - loss: 1.5872 - accuracy: 0.7306 - val_loss: 1.4601 - val_accuracy: 0.7931 - lr: 1.0000e-04
# Epoch 26/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.5511 - accuracy: 0.7231 - val_loss: 1.4650 - val_accuracy: 0.7736 - lr: 1.0000e-04
# Epoch 27/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.4765 - accuracy: 0.7417 - val_loss: 1.4360 - val_accuracy: 0.7806 - lr: 1.0000e-04
# Epoch 28/100
# 68/68 [==============================] - 5s 72ms/step - loss: 1.4096 - accuracy: 0.7778 - val_loss: 1.3634 - val_accuracy: 0.8097 - lr: 1.0000e-04
# Epoch 29/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.3785 - accuracy: 0.7699 - val_loss: 1.3182 - val_accuracy: 0.8097 - lr: 1.0000e-04
# Epoch 30/100
# 68/68 [==============================] - 5s 72ms/step - loss: 1.3517 - accuracy: 0.7968 - val_loss: 1.2953 - val_accuracy: 0.8125 - lr: 1.0000e-04
# Epoch 31/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.3047 - accuracy: 0.7940 - val_loss: 1.3210 - val_accuracy: 0.8069 - lr: 1.0000e-04
# Epoch 32/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.2781 - accuracy: 0.8005 - val_loss: 1.2410 - val_accuracy: 0.8278 - lr: 1.0000e-04
# Epoch 33/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.2277 - accuracy: 0.8255 - val_loss: 1.2105 - val_accuracy: 0.8458 - lr: 1.0000e-04
# Epoch 34/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.1962 - accuracy: 0.8301 - val_loss: 1.1898 - val_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 35/100
# 68/68 [==============================] - 5s 72ms/step - loss: 1.1651 - accuracy: 0.8375 - val_loss: 1.1789 - val_accuracy: 0.8403 - lr: 1.0000e-04
# Epoch 36/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.1568 - accuracy: 0.8292 - val_loss: 1.1372 - val_accuracy: 0.8583 - lr: 1.0000e-04
# Epoch 37/100
# 68/68 [==============================] - 5s 72ms/step - loss: 1.0908 - accuracy: 0.8477 - val_loss: 1.1546 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 38/100
# 68/68 [==============================] - 5s 73ms/step - loss: 1.0931 - accuracy: 0.8468 - val_loss: 1.1208 - val_accuracy: 0.8472 - lr: 1.0000e-04
# Epoch 39/100
# 68/68 [==============================] - 5s 72ms/step - loss: 1.0577 - accuracy: 0.8569 - val_loss: 1.1166 - val_accuracy: 0.8583 - lr: 1.0000e-04
# Epoch 40/100
# 68/68 [==============================] - 5s 74ms/step - loss: 1.0153 - accuracy: 0.8694 - val_loss: 1.0502 - val_accuracy: 0.8764 - lr: 1.0000e-04
# Epoch 41/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.9822 - accuracy: 0.8778 - val_loss: 1.0209 - val_accuracy: 0.8694 - lr: 1.0000e-04
# Epoch 42/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.9654 - accuracy: 0.8819 - val_loss: 1.0167 - val_accuracy: 0.8792 - lr: 1.0000e-04
# Epoch 43/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.9473 - accuracy: 0.8806 - val_loss: 0.9925 - val_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 44/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.9307 - accuracy: 0.8843 - val_loss: 0.9656 - val_accuracy: 0.8819 - lr: 1.0000e-04
# Epoch 45/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.9214 - accuracy: 0.8894 - val_loss: 0.9786 - val_accuracy: 0.8736 - lr: 1.0000e-04
# Epoch 46/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.8854 - accuracy: 0.8940 - val_loss: 0.9250 - val_accuracy: 0.8875 - lr: 1.0000e-04
# Epoch 47/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.8513 - accuracy: 0.9083 - val_loss: 0.9261 - val_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 48/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.8288 - accuracy: 0.9139 - val_loss: 0.9118 - val_accuracy: 0.8806 - lr: 1.0000e-04
# Epoch 49/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.8107 - accuracy: 0.9148 - val_loss: 0.8660 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 50/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.8018 - accuracy: 0.9167 - val_loss: 0.8894 - val_accuracy: 0.8875 - lr: 1.0000e-04
# Epoch 51/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.7867 - accuracy: 0.9116 - val_loss: 0.8542 - val_accuracy: 0.8972 - lr: 1.0000e-04
# Epoch 52/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.7589 - accuracy: 0.9176 - val_loss: 0.8630 - val_accuracy: 0.8833 - lr: 1.0000e-04
# Epoch 53/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.7340 - accuracy: 0.9296 - val_loss: 0.8441 - val_accuracy: 0.8986 - lr: 1.0000e-04
# Epoch 54/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.7246 - accuracy: 0.9324 - val_loss: 0.8109 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 55/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.7108 - accuracy: 0.9250 - val_loss: 0.8149 - val_accuracy: 0.8875 - lr: 1.0000e-04
# Epoch 56/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.6725 - accuracy: 0.9449 - val_loss: 0.7789 - val_accuracy: 0.9153 - lr: 1.0000e-04
# Epoch 57/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.6775 - accuracy: 0.9338 - val_loss: 0.8036 - val_accuracy: 0.8903 - lr: 1.0000e-04
# Epoch 58/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.6414 - accuracy: 0.9454 - val_loss: 0.7689 - val_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 59/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.6352 - accuracy: 0.9468 - val_loss: 0.7716 - val_accuracy: 0.9083 - lr: 1.0000e-04
# Epoch 60/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.6256 - accuracy: 0.9454 - val_loss: 0.7529 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 61/100
# 68/68 [==============================] - 5s 72ms/step - loss: 0.6222 - accuracy: 0.9454 - val_loss: 0.7639 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 62/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.5928 - accuracy: 0.9528 - val_loss: 0.7186 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 63/100
# 68/68 [==============================] - 5s 71ms/step - loss: 0.5950 - accuracy: 0.9468 - val_loss: 0.6861 - val_accuracy: 0.9194 - lr: 1.0000e-04
# Epoch 64/100
# 68/68 [==============================] - 5s 72ms/step - loss: 0.5797 - accuracy: 0.9481 - val_loss: 0.6823 - val_accuracy: 0.9153 - lr: 1.0000e-04
# Epoch 65/100
# 68/68 [==============================] - 5s 72ms/step - loss: 0.5601 - accuracy: 0.9542 - val_loss: 0.6790 - val_accuracy: 0.9208 - lr: 1.0000e-04
# Epoch 66/100
# 68/68 [==============================] - 5s 72ms/step - loss: 0.5588 - accuracy: 0.9500 - val_loss: 0.6741 - val_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 67/100
# 68/68 [==============================] - 5s 77ms/step - loss: 0.5372 - accuracy: 0.9593 - val_loss: 0.6581 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 68/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.5227 - accuracy: 0.9630 - val_loss: 0.6465 - val_accuracy: 0.9139 - lr: 1.0000e-04
# Epoch 69/100
# 68/68 [==============================] - 5s 72ms/step - loss: 0.5096 - accuracy: 0.9630 - val_loss: 0.6648 - val_accuracy: 0.9097 - lr: 1.0000e-04
# Epoch 70/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.5023 - accuracy: 0.9588 - val_loss: 0.6238 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 71/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4976 - accuracy: 0.9634 - val_loss: 0.6112 - val_accuracy: 0.9208 - lr: 1.0000e-04
# Epoch 72/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.4840 - accuracy: 0.9662 - val_loss: 0.6596 - val_accuracy: 0.9083 - lr: 1.0000e-04
# Epoch 73/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4655 - accuracy: 0.9694 - val_loss: 0.5856 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 74/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4549 - accuracy: 0.9718 - val_loss: 0.5980 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 75/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.4617 - accuracy: 0.9602 - val_loss: 0.6348 - val_accuracy: 0.9139 - lr: 1.0000e-04
# Epoch 76/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4579 - accuracy: 0.9657 - val_loss: 0.5698 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 77/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4279 - accuracy: 0.9727 - val_loss: 0.5700 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 78/100
# 68/68 [==============================] - 5s 73ms/step - loss: 0.4291 - accuracy: 0.9690 - val_loss: 0.5493 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 79/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4078 - accuracy: 0.9764 - val_loss: 0.5414 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 80/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.4184 - accuracy: 0.9657 - val_loss: 0.5482 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 81/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.4005 - accuracy: 0.9704 - val_loss: 0.5220 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 82/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3867 - accuracy: 0.9750 - val_loss: 0.5229 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 83/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.3960 - accuracy: 0.9731 - val_loss: 0.5188 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 84/100
# 68/68 [==============================] - 5s 74ms/step - loss: 0.3648 - accuracy: 0.9806 - val_loss: 0.5031 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 85/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3780 - accuracy: 0.9699 - val_loss: 0.5252 - val_accuracy: 0.9194 - lr: 1.0000e-04
# Epoch 86/100
# 68/68 [==============================] - 5s 76ms/step - loss: 0.3692 - accuracy: 0.9731 - val_loss: 0.5176 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 87/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3562 - accuracy: 0.9773 - val_loss: 0.4798 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 88/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3449 - accuracy: 0.9787 - val_loss: 0.4979 - val_accuracy: 0.9139 - lr: 1.0000e-04
# Epoch 89/100
# 68/68 [==============================] - 5s 76ms/step - loss: 0.3451 - accuracy: 0.9764 - val_loss: 0.4829 - val_accuracy: 0.9222 - lr: 1.0000e-04
# Epoch 90/100
# 68/68 [==============================] - 5s 76ms/step - loss: 0.3258 - accuracy: 0.9806 - val_loss: 0.4858 - val_accuracy: 0.9194 - lr: 1.0000e-04
# Epoch 91/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3199 - accuracy: 0.9787 - val_loss: 0.4523 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 92/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3168 - accuracy: 0.9796 - val_loss: 0.4532 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 93/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3086 - accuracy: 0.9787 - val_loss: 0.4467 - val_accuracy: 0.9389 - lr: 1.0000e-04
# Epoch 94/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.2913 - accuracy: 0.9861 - val_loss: 0.4542 - val_accuracy: 0.9444 - lr: 1.0000e-04
# Epoch 95/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.3029 - accuracy: 0.9810 - val_loss: 0.4529 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 96/100
# 68/68 [==============================] - 5s 76ms/step - loss: 0.3075 - accuracy: 0.9731 - val_loss: 0.4285 - val_accuracy: 0.9417 - lr: 1.0000e-04
# Epoch 97/100
# 68/68 [==============================] - 5s 76ms/step - loss: 0.2834 - accuracy: 0.9819 - val_loss: 0.4357 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 98/100
# 68/68 [==============================] - 5s 75ms/step - loss: 0.2826 - accuracy: 0.9806 - val_loss: 0.4468 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 99/100
# 68/68 [==============================] - 5s 77ms/step - loss: 0.2755 - accuracy: 0.9810 - val_loss: 0.4280 - val_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 100/100
# 68/68 [==============================] - 5s 76ms/step - loss: 0.2700 - accuracy: 0.9806 - val_loss: 0.4804 - val_accuracy: 0.9167 - lr: 1.0000e-04

# %%
import os
from tensorflow.keras.models import save_model

model_path = os.path.join(MODEL_PATH, "ravdess_cnn_model.h5")

if 'model' in globals():
    try:
        save_model(model, model_path)
        if os.path.isfile(model_path):
            print(f" Modelo CNN guardado en: {model_path}")
            print(f"   Tamaño: {os.path.getsize(model_path)/1024/1024:.2f} MB")
        else:
            print(" Error: El archivo no se creó correctamente")
    except Exception as e:
        print(f"Error al guardar el modelo: {str(e)}")
else:
    print("Error: El modelo no está definido en el entorno")
# Out:
#  Modelo CNN guardado en: /home/jhan/Documentos/modelo/ravdess_cnn_model.h5
#    Tamaño: 5.19 MB
# /tmp/ipykernel_33264/3962665367.py:8: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(model, model_path)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))

axs[0].plot(cnnhistory.history['loss'], label='Entrenamiento')
axs[0].plot(cnnhistory.history['val_loss'], label='Validación')
axs[0].set_title('Pérdida del Modelo')
axs[0].set_ylabel('Pérdida')
axs[0].set_xlabel('Época')
axs[0].legend()

axs[1].plot(cnnhistory.history['accuracy'], label='Entrenamiento')
axs[1].plot(cnnhistory.history['val_accuracy'], label='Validación')
axs[1].set_title('Precisión del Modelo')
axs[1].set_ylabel('Precisión')
axs[1].set_xlabel('Época')
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Save the model

# %%
model_name = 'Emotion_Voice_Detection_Model_CNN.h5'
save_dir = MODEL_PATH

os.makedirs(save_dir, exist_ok=True)

if 'model' in globals():
    model_path = os.path.join(save_dir, model_name)
    
    try:
        model.save(model_path)
        print(f'\n Modelo CNN guardado en: {model_path}')
        print(f'Tamaño: {os.path.getsize(model_path)/1024/1024:.2f} MB')
    except Exception as e:
        print(f' Error al guardar: {str(e)}')
else:
    print("Error: El modelo no está definido")
# Out:
#  Modelo CNN guardado en: /home/jhan/Documentos/modelo/Emotion_Voice_Detection_Model_CNN.h5
# Tamaño: 5.19 MB
# /home/jhan/Documentos/proyectoTesis/tesis/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Reloading the model to test it

# %%
from tensorflow.keras.models import load_model

model_path = os.path.join(MODEL_PATH, 'Emotion_Voice_Detection_Model_CNN.h5')

if os.path.isfile(model_path):
    try:
        loaded_model = load_model(model_path)
        print("\n" + "="*50)
        print(f"Modelo cargado de: {model_path}")
        print("Arquitectura:")
        loaded_model.summary()
        print("="*50)
    except Exception as e:
        print(f"Error al cargar: {str(e)}")
else:
    print(f" Archivo no encontrado: {model_path}")
# Out:
# ==================================================
# Modelo cargado de: /home/jhan/Documentos/modelo/Emotion_Voice_Detection_Model_CNN.h5
# Arquitectura:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 126, 256)          102656
#
#  batch_normalization (Batch  (None, 126, 256)          1024
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 63, 256)           0
#  D)
#
#  dropout (Dropout)           (None, 63, 256)           0
#
#  conv1d_1 (Conv1D)           (None, 61, 128)           98432
#
#  batch_normalization_1 (Bat  (None, 61, 128)           512
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 30, 128)           0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  flatten (Flatten)           (None, 3840)              0
#
#  dense (Dense)               (None, 64)                245824
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 448968 (1.71 MB)
# Trainable params: 448200 (1.71 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________
# ==================================================

# %% [markdown]
# # Checking the accuracy of the loaded model

# %%
if 'loaded_model' in globals() and 'x_testcnn' in globals() and 'y_test_int' in globals():
    loss, accuracy = loaded_model.evaluate(
        x_testcnn,
        y_test_int,
        verbose=1
    )
    
    print("\n" + "="*55)
    print("Evaluación del Modelo Cargado:")
    print(f"- Pérdida: {loss:.4f}")
    print(f"- Precisión: {accuracy * 100:.2f}%")
    print("="*55)
    
    best_val_acc = max(cnnhistory.history['val_accuracy'])
    print(f"\nMejor precisión en validación durante entrenamiento: {best_val_acc*100:.2f}%")
else:
    print("Error: Modelo o datos de prueba no disponibles")
# Out:
# 2025-07-04 18:39:30.978861: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 29952000 exceeds 10% of free system memory.
# 23/23 [==============================] - 1s 16ms/step - loss: 0.4804 - accuracy: 0.9167
#
# =======================================================
# Evaluación del Modelo Cargado:
# - Pérdida: 0.4804
# - Precisión: 91.67%
# =======================================================
#
# Mejor precisión en validación durante entrenamiento: 94.44%
